# %%
# data manipulation
import pandas as pd
import numpy as np
import scipy.io.arff

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# carregando o dataset
data, meta = scipy.io.arff.loadarff(f'data/speeddating.arff')
df = pd.DataFrame(data)

# Convertendo byte-strings para strings
str_df = df.select_dtypes([object]).stack().str.decode('utf-8').unstack()
for col in str_df:
    df[col] = str_df[col]

# ajeitar o tipo dos dados
nominal_cols = [col for col, dtype in zip(meta.names(), meta.types()) if dtype == 'nominal']
for col in nominal_cols:
    df[col] = df[col].astype('category')

df.head()
# Out:
#   has_null  wave  gender   age  age_o  d_age d_d_age  \
# 0        0   1.0  female  21.0   27.0    6.0   [4-6]
# 1        0   1.0  female  21.0   22.0    1.0   [0-1]
# 2        1   1.0  female  21.0   22.0    1.0   [0-1]
# 3        0   1.0  female  21.0   23.0    2.0   [2-3]
# 4        0   1.0  female  21.0   24.0    3.0   [2-3]
#
#                                     race  \
# 0  Asian/Pacific Islander/Asian-American
# 1  Asian/Pacific Islander/Asian-American
# 2  Asian/Pacific Islander/Asian-American
# 3  Asian/Pacific Islander/Asian-American
# 4  Asian/Pacific Islander/Asian-American
#
#                                   race_o samerace  ...  \
# 0            European/Caucasian-American        0  ...
# 1            European/Caucasian-American        0  ...
# 2  Asian/Pacific Islander/Asian-American        1  ...
# 3            European/Caucasian-American        0  ...
# 4               Latino/Hispanic American        0  ...
#
#    d_expected_num_interested_in_me  d_expected_num_matches like  \
# 0                            [0-3]                   [3-5]  7.0
# 1                            [0-3]                   [3-5]  7.0
# 2                            [0-3]                   [3-5]  7.0
# 3                            [0-3]                   [3-5]  7.0
# 4                            [0-3]                   [3-5]  6.0
#
#   guess_prob_liked d_like  d_guess_prob_liked  met  decision  decision_o  \
# 0              6.0  [6-8]               [5-6]  0.0         1           0
# 1              5.0  [6-8]               [5-6]  1.0         1           0
# 2              NaN  [6-8]               [0-4]  1.0         1           1
# 3              6.0  [6-8]               [5-6]  0.0         1           1
# 4              6.0  [6-8]               [5-6]  0.0         1           1
#
#    match
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#
# [5 rows x 123 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Data columns (total 123 columns):
#  #    Column                           Dtype
# ---   ------                           -----
#  0    has_null                         category
#  1    wave                             float64
#  2    gender                           category
#  3    age                              float64
#  4    age_o                            float64
#  5    d_age                            float64
#  6    d_d_age                          category
#  7    race                             category
#  8    race_o                           category
#  9    samerace                         category
#  10   importance_same_race             float64
#  11   importance_same_religion         float64
#  12   d_importance_same_race           category
#  13   d_importance_same_religion       category
#  14   field                            category
#  15   pref_o_attractive                float64
#  16   pref_o_sincere                   float64
#  17   pref_o_intelligence              float64
#  18   pref_o_funny                     float64
#  19   pref_o_ambitious                 float64
#  20   pref_o_shared_interests          float64
#  21   d_pref_o_attractive              category
#  22   d_pref_o_sincere                 category
#  23   d_pref_o_intelligence            category
#  24   d_pref_o_funny                   category
#  25   d_pref_o_ambitious               category
#  26   d_pref_o_shared_interests        category
#  27   attractive_o                     float64
#  28   sinsere_o                        float64
#  29   intelligence_o                   float64
#  30   funny_o                          float64
#  31   ambitous_o                       float64
#  32   shared_interests_o               float64
#  33   d_attractive_o                   category
#  34   d_sinsere_o                      category
#  35   d_intelligence_o                 category
#  36   d_funny_o                        category
#  37   d_ambitous_o                     category
#  38   d_shared_interests_o             category
#  39   attractive_important             float64
#  40   sincere_important                float64
#  41   intellicence_important           float64
#  42   funny_important                  float64
#  43   ambtition_important              float64
#  44   shared_interests_important       float64
#  45   d_attractive_important           category
#  46   d_sincere_important              category
#  47   d_intellicence_important         category
#  48   d_funny_important                category
#  49   d_ambtition_important            category
#  50   d_shared_interests_important     category
#  51   attractive                       float64
#  52   sincere                          float64
#  53   intelligence                     float64
#  54   funny                            float64
#  55   ambition                         float64
#  56   d_attractive                     category
#  57   d_sincere                        category
#  58   d_intelligence                   category
#  59   d_funny                          category
#  60   d_ambition                       category
#  61   attractive_partner               float64
#  62   sincere_partner                  float64
#  63   intelligence_partner             float64
#  64   funny_partner                    float64
#  65   ambition_partner                 float64
#  66   shared_interests_partner         float64
#  67   d_attractive_partner             category
#  68   d_sincere_partner                category
#  69   d_intelligence_partner           category
#  70   d_funny_partner                  category
#  71   d_ambition_partner               category
#  72   d_shared_interests_partner       category
#  73   sports                           float64
#  74   tvsports                         float64
#  75   exercise                         float64
#  76   dining                           float64
#  77   museums                          float64
#  78   art                              float64
#  79   hiking                           float64
#  80   gaming                           float64
#  81   clubbing                         float64
#  82   reading                          float64
#  83   tv                               float64
#  84   theater                          float64
#  85   movies                           float64
#  86   concerts                         float64
#  87   music                            float64
#  88   shopping                         float64
#  89   yoga                             float64
#  90   d_sports                         category
#  91   d_tvsports                       category
#  92   d_exercise                       category
#  93   d_dining                         category
#  94   d_museums                        category
#  95   d_art                            category
#  96   d_hiking                         category
#  97   d_gaming                         category
#  98   d_clubbing                       category
#  99   d_reading                        category
#  100  d_tv                             category
#  101  d_theater                        category
#  102  d_movies                         category
#  103  d_concerts                       category
#  104  d_music                          category
#  105  d_shopping                       category
#  106  d_yoga                           category
#  107  interests_correlate              float64
#  108  d_interests_correlate            category
#  109  expected_happy_with_sd_people    float64
#  110  expected_num_interested_in_me    float64
#  111  expected_num_matches             float64
#  112  d_expected_happy_with_sd_people  category
#  113  d_expected_num_interested_in_me  category
#  114  d_expected_num_matches           category
#  115  like                             float64
#  116  guess_prob_liked                 float64
#  117  d_like                           category
#  118  d_guess_prob_liked               category
#  119  met                              float64
#  120  decision                         category
#  121  decision_o                       category
#  122  match                            category
# dtypes: category(64), float64(59)
# memory usage: 4.3 MB

# %%
missing_values = 0
col_missing_values = 0

for col in df.columns:
    valores_ausentes = df[col].isna().sum()
    if valores_ausentes > 0:
        col_missing_values += 1
        print(f"{col} tem {valores_ausentes} valores ausentes")
    missing_values += valores_ausentes
# Out:
# age tem 95 valores ausentes
# age_o tem 104 valores ausentes
# importance_same_race tem 79 valores ausentes
# importance_same_religion tem 79 valores ausentes
# pref_o_attractive tem 89 valores ausentes
# pref_o_sincere tem 89 valores ausentes
# pref_o_intelligence tem 89 valores ausentes
# pref_o_funny tem 98 valores ausentes
# pref_o_ambitious tem 107 valores ausentes
# pref_o_shared_interests tem 129 valores ausentes
# attractive_o tem 212 valores ausentes
# sinsere_o tem 287 valores ausentes
# intelligence_o tem 306 valores ausentes
# funny_o tem 360 valores ausentes
# ambitous_o tem 722 valores ausentes
# shared_interests_o tem 1076 valores ausentes
# attractive_important tem 79 valores ausentes
# sincere_important tem 79 valores ausentes
# intellicence_important tem 79 valores ausentes
# funny_important tem 89 valores ausentes
# ambtition_important tem 99 valores ausentes
# shared_interests_important tem 121 valores ausentes
# attractive tem 105 valores ausentes
# sincere tem 105 valores ausentes
# intelligence tem 105 valores ausentes
# funny tem 105 valores ausentes
# ambition tem 105 valores ausentes
# attractive_partner tem 202 valores ausentes
# sincere_partner tem 277 valores ausentes
# intelligence_partner tem 296 valores ausentes
# funny_partner tem 350 valores ausentes
# ambition_partner tem 712 valores ausentes
# shared_interests_partner tem 1067 valores ausentes
# sports tem 79 valores ausentes
# tvsports tem 79 valores ausentes
# exercise tem 79 valores ausentes
# dining tem 79 valores ausentes
# museums tem 79 valores ausentes
# art tem 79 valores ausentes
# hiking tem 79 valores ausentes
# gaming tem 79 valores ausentes
# clubbing tem 79 valores ausentes
# reading tem 79 valores ausentes
# tv tem 79 valores ausentes
# theater tem 79 valores ausentes
# movies tem 79 valores ausentes
# concerts tem 79 valores ausentes
# music tem 79 valores ausentes
# shopping tem 79 valores ausentes
# yoga tem 79 valores ausentes
# interests_correlate tem 158 valores ausentes
# expected_happy_with_sd_people tem 101 valores ausentes
# expected_num_interested_in_me tem 6578 valores ausentes
# expected_num_matches tem 1173 valores ausentes
# like tem 240 valores ausentes
# guess_prob_liked tem 309 valores ausentes
# met tem 375 valores ausentes

# %%
df[df.eq('?').any(axis=1)].count()
# Out:
# has_null              136
# wave                  136
# gender                136
# age                    72
# age_o                  63
#                      ...
# d_guess_prob_liked    136
# met                   118
# decision              136
# decision_o            136
# match                 136
# Length: 123, dtype: int64

# %% [markdown]
# Temos valores não informados que estão representados como "?", iremos considerar como valor ausente e iremos tratar no pré-processamento.

# %%
valores_ausentes_linhas = df.isna().any(axis=1).sum()

# %%
print(f"{missing_values} valores ausentes")
print(f"{col_missing_values} colunas com valores ausentes")
print(f"{valores_ausentes_linhas} linhas com valores ausentes")
# Out:
# 18173 valores ausentes
# 57 colunas com valores ausentes
# 7330 linhas com valores ausentes

# %% [markdown]
# O dataset conta com 8378 registros e 123 features, sendo 64 features categóricas e 59 numéricas (float) e um total de 18173 valores ausentes, distribuidos em 57 colunas e 7330 linhas, sem contar com os valores que estão representados como "?". Algumas colunas apresentam poucos valores ausentes, como 79 (de um total de 8378), enquanto outras possuem uma quantidade significante faltando, como expected_num_interested_in_me com 6578 (78%) valores.

# %%
df.describe()
# Out:
#               wave          age        age_o        d_age  \
# count  8378.000000  8283.000000  8274.000000  8378.000000
# mean     11.350919    26.358928    26.364999     4.185605
# std       5.995903     3.566763     3.563648     4.596171
# min       1.000000    18.000000    18.000000     0.000000
# 25%       7.000000    24.000000    24.000000     1.000000
# 50%      11.000000    26.000000    26.000000     3.000000
# 75%      15.000000    28.000000    28.000000     5.000000
# max      21.000000    55.000000    55.000000    37.000000
#
#        importance_same_race  importance_same_religion  pref_o_attractive  \
# count           8299.000000               8299.000000        8289.000000
# mean               3.784793                  3.651645          22.495347
# std                2.845708                  2.805237          12.569802
# min                0.000000                  1.000000           0.000000
# 25%                1.000000                  1.000000          15.000000
# 50%                3.000000                  3.000000          20.000000
# 75%                6.000000                  6.000000          25.000000
# max               10.000000                 10.000000         100.000000
#
#        pref_o_sincere  pref_o_intelligence  pref_o_funny  ...        music  \
# count     8289.000000          8289.000000   8280.000000  ...  8299.000000
# mean        17.396867            20.270759     17.459714  ...     7.851066
# std          7.044003             6.782895      6.085526  ...     1.791827
# min          0.000000             0.000000      0.000000  ...     1.000000
# 25%         15.000000            17.390000     15.000000  ...     7.000000
# 50%         18.370000            20.000000     18.000000  ...     8.000000
# 75%         20.000000            23.810000     20.000000  ...     9.000000
# max         60.000000            50.000000     50.000000  ...    10.000000
#
#           shopping         yoga  interests_correlate  \
# count  8299.000000  8299.000000          8220.000000
# mean      5.631281     4.339197             0.196010
# std       2.608913     2.717612             0.303539
# min       1.000000     0.000000            -0.830000
# 25%       4.000000     2.000000            -0.020000
# 50%       6.000000     4.000000             0.210000
# 75%       8.000000     7.000000             0.430000
# max      10.000000    10.000000             0.910000
#
#        expected_happy_with_sd_people  expected_num_interested_in_me  \
# count                    8277.000000                    1800.000000
# mean                        5.534131                       5.570556
# std                         1.734059                       4.762569
# min                         1.000000                       0.000000
# 25%                         5.000000                       2.000000
# 50%                         6.000000                       4.000000
# 75%                         7.000000                       8.000000
# max                        10.000000                      20.000000
#
#        expected_num_matches         like  guess_prob_liked          met
# count           7205.000000  8138.000000       8069.000000  8003.000000
# mean               3.207814     6.134087          5.207523     0.049856
# std                2.444813     1.841285          2.129565     0.282168
# min                0.000000     0.000000          0.000000     0.000000
# 25%                2.000000     5.000000          4.000000     0.000000
# 50%                3.000000     6.000000          5.000000     0.000000
# 75%                4.000000     7.000000          7.000000     0.000000
# max               18.000000    10.000000         10.000000     8.000000
#
# [8 rows x 59 columns]

# %%
# distribuição das variáveis numéricas
cols = [
    'gender', 'age', 'd_age', 'importance_same_race', 'importance_same_religion', 'attractive_important',
    'sincere_important', 'intellicence_important', 'funny_important', 'ambtition_important', 'shared_interests_important',
    'attractive', 'sincere', 'intelligence', 'funny', 'ambition', 'attractive_partner', 'sincere_partner', 
    'intelligence_partner', 'funny_partner', 'ambition_partner', 'shared_interests_partner', 'gaming',
    'reading', 'expected_happy_with_sd_people', 'expected_num_interested_in_me',
    'expected_num_matches', 'like', 'guess_prob_liked', 'met', 'decision', 'match'
]

num_cols = len(cols)
num_rows = (num_cols // 4) + 1

fig, axes = plt.subplots(num_rows, 4, figsize=(20, num_rows * 4))
axes = axes.flatten()

for i, column in enumerate(df[cols].columns):
    sns.histplot(df[column], ax=axes[i], kde=True)
    axes[i].set_title(column)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# distribuição das classes
ax = sns.histplot(df['match'])
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %% [markdown]
# Podemos fazer algumas observações a partir desses gráficos:
# - Temos a mesma quantidade de homens e mulheres.
# - Tem um grande desbalanceamento das classes (6998 da classe negativa contra cerca de 1380 da classe positiva), o que provavelmente fará com que precisemos usar alguma técnica para lidar com o desbalancamento, caso haja grandes diferenças em métricas como recall para cada uma das classes.
# - A maioria das pessoas tem entre 20 e 30 anos, mas existe pessoas com mais de 40 anos.
# - A maioria das diferenças entre idade é de 0 a 10 anos, mas existe diferença com mais de 20 anos, e até mesmo uma com 37 anos.
# - A maioria das pessoas não se importa muito quanto à raça e à religião do parceiro.
# - Gaming tem valores com 14 e Reading com 12, o que é uma inconsistência, já que os valores deveriam ir de 1 a 10.
# - Os participantes esperam que cerca de 2 a 5 pessoas irão se interessar neles.
#
# De maneira geral, as pessoas não atribuem muita importância aos atributos listados (geralmente fica em torno de 20, até cerca de 30), com alguns sendo excepcionalmente baixos, como ambição, cuja moda é 10. Vemos que as pessoas se consideram atrativas num nivel entre 7 e 8 de 10, se consideram muito sinceras, inteligentes, engraçadas e ambiciosas. Seria interessante comparar o que as pessoas acham de si mesmo com o que as outras pessoas acham. Aparentemente parece estar meio equilibrado, olhando separadamente os gráficos. As pessoas não parecem ter grandes expectativas para o SpeedDating, ficando em torno de 4-5 a expectativa de ser feliz com o SD, enquanto que o "like" ficou em torno de 7-6, o que mostra que o experimento superou as expectativas.

# %% [markdown]
# Podemos observar também que existe uma diferença nas escalas dos atributos, enquanto alguns estão na escala de 1 a 10, outros estão na escala de 1 a 100. Pode ser interessante utilizar alguma técnica de scaling, como MinMax, para fazer com que todos as variáveis fiquem na mesma escala, o que ajudaria algoritmos como KNN, onde diferentes escalas podem dominar umas as outras.

# %%
numeric_columns = df.select_dtypes(include=['number'])
# dropando colunas nao muito interessantes ou que os dados se repetem, como pref_o_atributo e atributo_important
numeric_columns.drop(
    columns=[
        'wave', 'age_o', 'd_age', 'interests_correlate', 'attractive_important',
        'sincere_important', 'intellicence_important', 'funny_important',
        'ambtition_important', 'shared_interests_important'
        ],
      inplace=True
    )

# %%
df_melted = numeric_columns.melt(var_name="Column", value_name="Value")

plt.figure(figsize=(12, 6))

# boxplot
sns.boxplot(x="Column", y="Value", data=df_melted, palette='coolwarm', flierprops={"marker": "o", "markerfacecolor": "red", "markersize": 6})

plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title("Boxplot")
plt.show()
# Out:
# /var/folders/td/6s38kfns7m30h4yz8m9_0r6m0000gn/T/ipykernel_5445/105454958.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Column", y="Value", data=df_melted, palette='coolwarm', flierprops={"marker": "o", "markerfacecolor": "red", "markersize": 6})

# %% [markdown]
# Aqui vemos que existem muitos possíveis outliers (não necessariamente são outliers, é necessário fazer uma análise com conhecimento de domínio). Acreditamos que esses valores não são inconsistências, com exceção de gaming e reading (que passam de 10, quando deveriam ser valores entre 1 e 10).

# %%
threshold = 0.5

corr_matrix = numeric_columns.corr()

masked_corr = corr_matrix.copy()
np.fill_diagonal(masked_corr.values, np.nan)

significant_columns = masked_corr.columns[
    (masked_corr.abs() > threshold).any(axis=0)
]

filtered_corr_matrix = corr_matrix.loc[significant_columns, significant_columns]

plt.figure(figsize=(12, 10))
mask = np.triu(np.ones_like(filtered_corr_matrix, dtype=bool))
sns.heatmap(
    filtered_corr_matrix,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    linewidths=0.5,
    square=True,
    annot_kws={'size':10}
)

plt.title("Heatmap das Correlações dos Atributos", fontsize=16)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# Aqui podemos ver que temos algumas colunas relativamente bem correlacionadas, sendo talvez interessante aplicar alguma forma de tratamento para diminuir a quantidade de colunas muito correlacionadas, como Principal Component Analysis.
